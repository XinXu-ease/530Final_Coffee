# %% [markdown]
# <a href="https://colab.research.google.com/github/XinXu-ease/530Final_Coffee/blob/main/Coffee_review.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ucimlrepo
# Out:
# Requirement already satisfied: ucimlrepo in /usr/local/lib/python3.12/dist-packages (0.0.7)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ucimlrepo) (2.2.2)
# Requirement already satisfied: certifi>=2020.12.5 in /usr/local/lib/python3.12/dist-packages (from ucimlrepo) (2025.11.12)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->ucimlrepo) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->ucimlrepo) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.17.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from ucimlrepo import fetch_ucirepo

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("schmoyote/coffee-reviews-dataset")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'coffee-reviews-dataset' dataset.
# Path to dataset files: /kaggle/input/coffee-reviews-dataset

# %%
df = pd.read_csv("/kaggle/input/coffee-reviews-dataset/coffee_analysis.csv")
df.head()
# Out:
#                          name                    roaster         roast  \
# 0     “Sweety” Espresso Blend                     A.R.C.  Medium-Light
# 1        Flora Blend Espresso                     A.R.C.  Medium-Light
# 2    Ethiopia Shakiso Mormora               Revel Coffee  Medium-Light
# 3          Ethiopia Suke Quto                Roast House  Medium-Light
# 4  Ethiopia Gedeb Halo Beriti  Big Creek Coffee Roasters        Medium
#
#      loc_country        origin_1           origin_2  100g_USD  rating  \
# 0      Hong Kong          Panama           Ethiopia     14.32      95
# 1      Hong Kong          Africa       Asia Pacific      9.05      94
# 2  United States       Guji Zone  Southern Ethiopia      4.70      92
# 3  United States       Guji Zone      Oromia Region      4.19      92
# 4  United States  Gedeb District         Gedeo Zone      4.85      94
#
#      review_date                                             desc_1  \
# 0  November 2017  Evaluated as espresso. Sweet-toned, deeply ric...
# 1  November 2017  Evaluated as espresso. Sweetly tart, floral-to...
# 2  November 2017  Crisply sweet, cocoa-toned. Lemon blossom, roa...
# 3  November 2017  Delicate, sweetly spice-toned. Pink peppercorn...
# 4  November 2017  Deeply sweet, subtly pungent. Honey, pear, tan...
#
#                                               desc_2  \
# 0  An espresso blend comprised of coffees from Pa...
# 1  An espresso blend comprised of coffees from Af...
# 2  This coffee tied for the third-highest rating ...
# 3  This coffee tied for the third-highest rating ...
# 4  Southern Ethiopia coffees like this one are pr...
#
#                                               desc_3
# 0  A radiant espresso blend that shines equally i...
# 1  A floral-driven straight shot, amplified with ...
# 2  A gently spice-toned, floral- driven wet-proce...
# 3  Lavender-like flowers and hints of zesty pink ...
# 4  A deeply and generously lush cup saved from se...

# %% [markdown]
# # EDA

# %%
df.describe()
# Out:
#           100g_USD       rating
# count  2095.000000  2095.000000
# mean      9.323313    93.114081
# std      11.430659     1.563024
# min       0.120000    84.000000
# 25%       4.930000    92.000000
# 50%       5.860000    93.000000
# 75%       8.785000    94.000000
# max     132.280000    98.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2095 entries, 0 to 2094
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         2095 non-null   object
#  1   roaster      2095 non-null   object
#  2   roast        2080 non-null   object
#  3   loc_country  2095 non-null   object
#  4   origin_1     2095 non-null   object
#  5   origin_2     2095 non-null   object
#  6   100g_USD     2095 non-null   float64
#  7   rating       2095 non-null   int64
#  8   review_date  2095 non-null   object
#  9   desc_1       2095 non-null   object
#  10  desc_2       2095 non-null   object
#  11  desc_3       2093 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 196.5+ KB

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 5))
sns.histplot(df['rating'], kde=True)
plt.title('Distribution of Rating')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['100g_USD'], kde=True)
plt.title('Distribution of Price')
plt.xlabel('Price (100g/$)')
plt.ylabel('Frequency')
plt.show()

# %%
#checking for missing values
df.isnull().sum()
# Out:
# name            0
# roaster         0
# roast          15
# loc_country     0
# origin_1        0
# origin_2        0
# 100g_USD        0
# rating          0
# review_date     0
# desc_1          0
# desc_2          0
# desc_3          2
# dtype: int64

# %%
df["desc_3"] = df["desc_3"].fillna("")

# %%
cat_cols = ["roast", "loc_country", "origin_1", "origin_2", "roaster"]
num_cols = ["100g_USD"]
df["text"] = df["desc_1"] + " " + df["desc_2"] + " " + df["desc_3"]
text_col = "text"

# %%
unique_values = {}
for col in cat_cols:
    unique_values[col] = df[col].unique()
    print(f"Unique values in {col}: {unique_values[col]}")
# Out:
# Unique values in roast: ['Medium-Light' 'Medium' 'Light' 'Medium-Dark' nan 'Dark']
# Unique values in loc_country: ['Hong Kong' 'United States' 'Canada' 'Taiwan' "Hawai'i" 'Australia'
#  'England' 'Uganda' 'Mexico' 'Belgium' 'United States And Floyd'
#  'Guatemala' 'Japan' 'Peru' 'Honduras' 'China' 'Kenya' 'Malaysia'
#  'New Taiwan']
# Unique values in origin_1: ['Panama' 'Africa' 'Guji Zone' 'Gedeb District' 'Odo Shakiso District'
#  'Yirgacheffe Growing Region' 'Hambela Wamena District' 'Hambela District'
#  'Sidama (Also Sidamo) Growing Region' 'Central Kenya' 'Tore Village'
#  'Ethiopia' 'Colombia' 'Yirgacheffe' 'Holualoa' 'Kirinyaga District'
#  'Nyeri Growing Region' 'Mexico' 'Nakuru Province'
#  'San Martin Jilotepeque' 'Kericho County' 'Santa Rosa' 'Gichugu Division'
#  'Aleta Wondo' 'Huila' 'Kirumba' 'Nakuru County'
#  'Nueva Segovia Growing Region' 'Biolley' 'Kochere' 'Piedra Candela'
#  'Santa Ana Department' 'Boquete Growing Region' 'South-Central Kenya'
#  'Horcheta' 'Narino Department' 'Paso Ancho' "Ka'U Growing Region"
#  'Gatundu' 'Doi Pangkhon Growing Region' 'Northern Sumatra'
#  'Southern Tolima Department' 'Haraz Growing Region' 'Captain Cook'
#  'Chimaltenango Department' 'Jinotega' 'Mukaro' 'Marcala Growing Region'
#  'Kiambu County' 'Copan' 'Nyamagabe District' 'Sidamo Growing Region'
#  'Huila Department' 'Gayo (Also Aceh) Growing Region' 'Chiriqui Province'
#  'Central Valley' 'Brazil And Four Other Origins' 'Brazil'
#  'Tolima Department' 'Agaro District'
#  'Sidamo (Also Sidama) Growing Region' 'Cajamarca' 'El Salvador'
#  'Costa Rica' 'Central America' 'Guatemala' 'Kenya' 'Gaitania'
#  'Gikongoro Prefecture' 'Gedeo Zone' 'Sabanilla De Alajuela'
#  'Bhirkune Village' 'Tarrazu Growing Region' 'Peru'
#  'Lintong Growing Region' 'Kahale' 'Buhinyuza District'
#  'Pichincha Growing Region' 'Al-Durrar' 'Cundinamarca Department'
#  'Valle Del Cauca Growing Region' 'Flores Island' 'Toraja Growing Region'
#  'Northern Burundi' 'Mantiqueira De Minas Growing Region'
#  'Matas De Minas Growing Region' 'Chapada Diamantina Growing Region'
#  'Rwanda' 'Kayanza' 'Ethopia' 'Yemen' 'Monteverde' 'Kalehe'
#  'Gitega Province' 'Chalatenango Growing Region' 'Burundi'
#  'Nariño Department' 'Carmo De Minas Growing Region'
#  'Southern Minas Gerais State' 'Sul De Minas Growing Region'
#  'Minas Gerais State' 'Ethiopia Natural Yirgacheffe Adado Shara'
#  'Embu County' 'Kayanza Province' 'Nyamasheke' 'Gakenke District'
#  'Kapchorwa District' 'Tarime District' 'Zambia' 'São Sebastião Da Grama'
#  'Sabanilla De Alajuela Growing Region' 'Shakiso District' 'Central Yemen'
#  'West Guji Zone' 'Huehuetenango Department' 'Cajamarca Region'
#  "Murang'A County" 'Palencia' 'Huehuetenango Growing Region' 'Antoquia'
#  'Bita Genet District' 'San Agustín Growing Region'
#  'Acatenango Growing Region' 'Bahia' 'Limu Woreda' 'Huehuetenango'
#  'Metapan' 'Planadas' 'Horqueta' 'Bench-Maji Zone' 'Oromia Region'
#  'Thika Growing Region' 'El Boquerón Growing Region' 'Lake Amatitlán Area'
#  'Buhoma' 'Llano Bonito' 'Antioquia' 'Antigua Growing Region'
#  'La Providencia' 'Acatenango' 'Matagalpa Growing Region' 'Apaneca'
#  'Alto Quiel' 'Jaramillo' 'Santander' 'Santa Ana Region' 'Jimma Zone'
#  'Poás Volcano Region' 'Jutiapa Department' 'Alaka District'
#  'São Sebastião De Grama' 'Aceh Growing Region' 'Chalatenango'
#  'Northern Thailand' 'Santa Bárbara' 'South America' 'Caldas Department'
#  'Rustiro District' 'Arusha Region' 'Chinchipe' 'Pichincha Province'
#  'Pasco Growing Region' 'Satipo Province' 'Jaén Province'
#  'Caranavi Province' 'Rulindo' 'Region Concepción Huista'
#  'Mara Growing Region' 'Bench Maji Zone' 'Kirinyaga County'
#  'Palestina Region' 'Campos Alto District'
#  'Harar (Also Harrar) Growing Region Of Eastern Ethiopia'
#  'Kona Growing District' 'San Ignacio Province' 'Loja Province'
#  'Utcubamba Province' 'Muranga District' 'Sabah State'
#  'Salgar Municipality' 'South Kivu Province' 'Nyamasheke District'
#  'Simalungun Regency' 'Puna District' 'Kona District' 'Kula' 'Kealakekua'
#  'Bani Matar Growing Region' 'San Augustin' 'Caldas Growing Region'
#  'Kiambu Growing Region' 'Ibicoara Municipality' 'Coto Brus'
#  'Bururi Growing Region' 'Congo' 'Northern Province' 'Kalaheo'
#  'Oaxaca State' 'Sandy Bay Valley' 'Belis' 'Kochere Woreda'
#  'Eastern Highlands' 'Asia' 'Tecapa Chinameca Growing Region' 'La Palma'
#  'Chalatenango Department' 'Chiriqui Growing Region' 'Alto Jaramillo'
#  'Neira' 'San Cristobal' 'Cusco Department' 'La Libertad' 'Valle De Cauca'
#  'La Mesa' 'Tarrazu' 'Sidamo (Also Sidama)' 'Cauca' 'Brunca'
#  'Thika Plateau' 'Muranga County' 'Jamaica' 'Jimma Growing Region'
#  'Yeri Growing Region' 'Mandheling Growing Region'
#  'Santa Rosa Growing Region' 'Buyenzi' 'Indonesia' 'Oromia' 'Volcan'
#  'Kibugu Village' 'Antigua' 'Chimaltenango' 'Cerro El Tigre' 'Puna'
#  'Nensebo Woreda' 'Dolores' 'Kona' 'Nicaragua' 'Sumatra' 'Madagascar'
#  'Sololá' 'Santa Elena' 'Boquete' 'Apaneca-Ilamatepec Mountain Range'
#  'Karatu' 'Sidama (Also Sidamo) Region' 'Ngiriambu District'
#  'Cajamarca Growing Region' 'Iambu Growing Region' 'Quiché'
#  'Kona Growing Region' 'Junin' 'El Socorro' 'Motozintla De Mendoza'
#  'Sidama Growing Region' 'Gakenke' 'Lake Kivu' 'Kiambi County' 'Musasa'
#  'Murutra' 'Ka’U Growing Region' 'Namasheke District' 'Al-Haimah'
#  'Quilanga' 'Vale De Grama' 'South Kivu' 'Boneza' 'Ka’U' 'Pitalito'
#  'South Kona Growing Region' 'Idamo (Also Sidama) Growing Region'
#  'Bungoma' 'Pinchincha' 'Nariño' 'Agaro Gera' 'Jambi Province'
#  'North Kona Growing District' 'Bali' 'Biollet' 'Caranavi' 'Aceh Province'
#  'Huabal' 'El Diamante' 'Paéz' 'Pantan Musara' 'Alishan' 'Inza' 'San Jose'
#  'Ipanema' 'Tobosi' 'Yunnan Province' 'Kirinyaga' 'Acevedo'
#  'Central Rwanda' 'Ahuachapan' 'Volcano' 'Nueva Segovia' 'Tolima'
#  'Isla Santa Cruz And Isla San Cristóbal' 'Kwazulu-Natal Province'
#  'Antioquia Department' 'Worka Chelbessa' 'Wood Valley' 'Ngozi Province'
#  'Suaza' 'Dipilto' "Ka'U Growing District" 'Kisii' 'Mbeya'
#  'Bungoma Region' 'Thiotte' 'Sevilla' 'Embu' 'Aceh' 'Chiapas' 'Las Flores'
#  'Santa Barbara' 'Illubabor Zone' 'Santa Maria De Dota' 'Purosa Village'
#  'Canton De Desamparados' 'Matagalpa' 'Bella Vista' 'Chaguites'
#  'Alotepec-Metapan Region' 'Honduras' 'Taiwan' 'Doi Pangkhon'
#  'Buenos Aires' 'Oaxaca' 'Chiriqui' 'Bombe Mountains' 'Corquin'
#  'Nyeri County' 'Fraijanes Growing Region' 'Suchitan'
#  'Puna Growing Region' 'Cundinamarca' 'Nueva Suiza' 'Djimma'
#  'Cobán Growing Region' 'Songwe Region' 'Naranjo' 'Central Province'
#  'Arbegona' 'Gedeo' 'Pasco Department' 'La Paz' 'Jarabacoa'
#  'Omkoi District' 'Veracruz' 'Marcala' 'Los Planes' 'Keramo Village'
#  'Villa Rica' 'Llayla District' 'Western Highlands Province'
#  'Taitung Luan Mountain' 'Tha Sae' 'Columbia' 'Sun Moon Lake' 'Chirinos'
#  'Central Plateau' 'San Cristobal Acasaguastlán' 'Quindío Department'
#  'San José' 'Conganama' 'Liboriana Valley' 'Panchia' 'Tres Cruces'
#  'Volcan Growing Region' 'Alajuela' "Ka'U District" 'Kainaliu' 'Chito'
#  'Los Naranjos' 'Chinas' 'Yautepec/Miahuatlan' 'Fraijanes Plateau'
#  'San Cristobal Cucho' 'San Ignacio' 'Chiang Rai Province'
#  'Canton Lomas De San Marcelino' 'Antón Montañita' 'Oromia Growing Region'
#  'Puno' 'Yunlin' 'La Fundadora' 'Papua New Guinea' 'Haiti'
#  'Muhanga District' 'Wenango District' 'Cerrado Growing Region'
#  'Huai Mae Liam' 'Risaralda Department' 'Cusco' 'Ainantu District'
#  'Kainantu District' 'Haraaz Growing Region' 'Congonama' 'Algeciras'
#  'Caicedo' 'Cauca Department' 'Kerinci Highlands' 'Atitlán Growing Region'
#  'Bebesen District' 'Amhara Region' 'El Soccoro' 'Sipi Falls' 'Trujillo'
#  'Nariño Region' 'Paez Region' 'Huye District' 'Renacimiento District'
#  'El Guarco' 'Coban' 'Caldas' 'Banz' 'Nan Province' 'Chiapas State'
#  'Los Angeles' 'Hayisa Village' 'Caicedonia' 'Pasto'
#  'Yirgachefffe Growing Region' 'Rutsiro' 'Gerbicho Rogicha'
#  'Mount Kenya Growing Region' 'Risaralda' 'Urrao' 'Western Highlands'
#  'Sidamo Zone' 'South Kivu Growing Region' 'Ngorongoro Crater Region'
#  'Gakenke Growing Region' 'Kayanza State' 'Nyaruguru District' 'Ngorogoro'
#  'Sidama Zone' 'Uraga District' 'Rosario De Desamparados'
#  'Finca Santa Teresa' 'Pitalito-Bruselas' 'Blue Mountain Growing Region'
#  'San Isidro' 'Sana’A Growing Region' 'Santander Department'
#  'Rutsiro District' 'Jaen' 'Copey District' 'Ochere Woreda' 'Vereda'
#  'Kabiufa' 'Aratoca' 'Savane Zombie' 'Ngorongoro'
#  'Valle Del Cauca Department' 'Sa’Dah Governorate' 'Fraijanes'
#  'Lake Amatitlán Region' 'Acatenango Valley' 'Santa Elena Province'
#  'Ngila Estate' 'Pluma Hidalgo' 'Karongi District' 'Chiriquí'
#  'Vale Da Grama' 'San Juan La Laguna' 'El Progresso' 'Banti Nenga' 'Dalat'
#  'Calzontes Arriba' 'Al Hayma Region' 'Al Mahjr' 'Al Wadi Region'
#  'Jabal Haraz' 'Bani Matar' 'Al Hayma District' 'Sana’A Governorate'
#  'Siguatepeque' 'Sama' 'Uraga' 'Mathira West District' 'Java'
#  'Lourdes De Naranjo' 'Worka-Sakaro' 'Chelchele' 'Hambela Wamena'
#  'Sierra Madre' 'Kurtistown' 'San Augustín' 'La Argentina' 'Bolivia'
#  'Hambela Dimtu' 'San Vito' 'Llano Bonito De Narajo' 'Bona Zuria'
#  'Sidama Region' 'Cañas Verdes' 'Tierras Altas' 'Potrerillo Arriba'
#  'Jurutungo' 'Benguet' 'Concepción Huista' 'Alotenango' 'Cobán'
#  'El Progresso Department' 'Huila Colombia' 'Al Mashtal Ul Burhani'
#  'Hayma Dakhiliya Growing Region' 'Dondon' 'Simalungun' 'Brunca Region'
#  'Ocotepeque Department' 'Konga Village' 'New Oriente Growing Region'
#  'Cantón El Tunel' 'Apaneca Ilamatepec Mountain Range' 'Piendamó'
#  'Jinotega Department' 'Tanzania' 'Pallatanga' 'Lintongnihuta'
#  'Gunung Tujuh' 'India' 'La Piedra De Rivas' 'Junín Province'
#  'Huehuetenengo Department' 'Villa Rica District' 'San Jose De Minas'
#  'Mount Kerinci Highlands' 'Americas' 'Latin America' 'Amaybamba'
#  'Buesaco' 'Maunawili Growing Region' 'Yautepec' 'Kebele Buku Sayisa'
#  'Nyakibanda' 'Ka‘Ū' 'Upper Waghi Valley' 'Western Province' 'Haraaz'
#  'Pematang Purba' 'Brunca Growing Region' 'Sharqi'
#  'Santo Antônio Do Amparo' 'Serra Da Mantiqueira' 'Cerrado Mineiro'
#  'Alto Caparaó' 'Chapada Diamantina Region' 'Campestre'
#  'Mogiana Growing Region' 'Quindio Department' 'Atok' 'Quito'
#  'Pacaybamba Growing Region' 'San Lorenzo' 'Volcán Growing Region'
#  'Giraldo' 'Rivas District' 'Santa Barbara Department' 'Mbozi'
#  'Benguet Province' 'Tarrazú Growing Region' 'Pitalito Municipality'
#  'Chiriquí Province' 'Carrillos Alto De Poás' 'Dota' 'Mercedes Sur'
#  'Ibarra' 'Ka‘Ū Growing Region' 'West Valley' 'Los Santos'
#  'Apaneca-Ilamatepec Growing Region' 'Monte Verde'
#  'Pitalito Growing Region' 'Djimmah' 'Cau Dat' 'Vereda Santa Rita'
#  'San José De Minas' 'Cusco Province' 'Coatepec' 'La Union' 'La Coipa'
#  'Kochere District' 'Mirado Village' 'Bombe Village' 'Nyarita' 'La Cañada'
#  'Karundu' 'Huarango' 'Dominican Republic' 'Cap Haitien' 'Pingtung'
#  'Thailand' 'Lam Dong Province' 'Muhanga' 'Guerrero State' 'Los Altos'
#  'Las Margaritas' 'Cusco Region' 'La Dalia' 'Alishan Township'
#  'Djimma Growing Region' 'Masaguara' 'Tarrazú' 'Pijao' 'Armenia'
#  'Saraguro' 'Tojquia' 'Villa Canales' 'San Lucas Tolimán'
#  'Lake Atitlán Growing Region']
# Unique values in origin_2: ['Ethiopia' 'Asia Pacific' 'Southern Ethiopia' 'Oromia Region'
#  'Gedeo Zone' 'Guji Zone' 'Sidama (Also Sidamo) Growing Region'
#  'Yirgacheffe Growing Region' 'South America' 'Kenya'
#  'North Kona Growing District' 'South-Central Kenya'
#  'Chimaltenango Department' 'La Unión Department' 'Kirinyaga County'
#  'Colombia' 'North Kivu Province' 'Costa Rica' 'Nicaragua'
#  'Southern Costa Rica' 'Chiriqui Province' 'El Salvador' 'Western Panama'
#  'Boquete Growing Region' 'Southern Colombia' 'Volcan'
#  'Big Island Of Hawaii' 'Thika Province' 'Northern Thailand' 'Indonesia'
#  'West-Central Colombia' 'North-Central Yemen' 'Guatemala'
#  'Nyeri Growing Region' 'La Paz Department' 'Honduras' 'Southern Province'
#  'South-Central Ethiopia' 'Aceh Province' 'Far Western Panama'
#  'Center-West Colombia' 'Jimma Zone' 'Peru' 'Tolima Department'
#  'South-Central Rwanda' 'Central Valley' 'Nuwakot District'
#  'Tarrazu Growing Region' 'North Sumatra Province' 'South Kivu Province'
#  'Burundi' 'Muhinga Province' 'Northern Ecuador' 'Sana’A Governorate'
#  'Lintong Growing Region' 'South-Central Sulawesi' 'Toraja Growing Region'
#  'Southern Minas Gerais State' 'Eastern Minas Gerais State' 'Bahia State'
#  'Chapada Diamantina Growing Region' 'Kabuye' 'Kayanza' 'Rwanda' 'Ethopia'
#  'Sumatra' 'Northwest El Salvador' 'Brazil' 'Narino Department'
#  'Northeastern Minas Gerais State' 'Southeastern Brazil'
#  'Minas Gerais State' 'Not Disclosed' 'Eastern Province Kenya'
#  'Central And South America' 'Muyinga Province' 'Northern Province'
#  'Eastern Region' 'Mara Region' 'São Paulo State'
#  'Sabanilla De Alajuela Growing Region' 'Southwestern Colombianar'
#  'Northern Peru' 'Central Kenya' 'Fraijanes Plateau Growing Region'
#  'Keffa Zone' 'Huila Department' 'Central Guatemala'
#  'Hambela Wamena District' 'Chiriquí' 'Kirinyaga District' 'Kiambu County'
#  'Bench-Maji Zone' 'Southwest Ethiopia' 'Kochere'
#  'El Boquerón Growing Region' 'South-Central Guatemala' 'Papua New Guinea'
#  'Southwest Uganda' 'Naranjo' 'Eastern Province' 'Sidamo' 'Embu County'
#  'Jalapa' 'Acatenango' 'Ahuachapán Department' 'Santander' 'Oromia State'
#  'Central Costa Rica' 'Southern Tolima Growing Region' 'West Guji Zone'
#  'Caldas Department' 'Western Province' 'Santa Maria' 'Northern Tanzania'
#  'Zamora Province' 'North-Central Ecuador' 'Oxapampa' 'Junin Region'
#  'Cajamarca Region' 'Huehuetenango Growing Region' 'Tarime'
#  'Southwestern Ethiopia' 'Rulindo' 'Southern Ecuador' 'Amazonas Region'
#  'Central Province' 'Malaysia' 'Antioquia Department'
#  'Democratic Republic Of The Congo' "Big Island Of Hawai'I"
#  'Kealakekua Growing Region' 'Island Of Maui' 'Kona Growing District'
#  'Yemen' 'Ecuador' 'Sidamo (Also Sidama) Growing Region' 'Huila'
#  'Central Colombia' 'Panama' 'Panana' 'Oromia Growing Region'
#  'Chapada Diamantina Region' 'Puntarenas' 'Coto Brus' 'Congo' 'Zambia'
#  'Kauai' 'Asia' 'Mexico' 'Saint Helena Island' 'Atok' 'Africa'
#  'Santiago De María' 'Southeastern El Salvador' 'Chalatenango Department'
#  'Northwestern El Salvador' "Murang'A County" 'Cobán'
#  'La Convención Province' 'Huehuetenango' 'Cundinamarca'
#  'Central Highlands' 'Muranga County' 'Jamaica' 'Northern Sumatra'
#  'Central America' 'Santa Rosa Growing Region' 'Katanga'
#  'Big Island Of Hawai’I' 'Sidama' 'Dolores' 'Odo Shakiso District'
#  'La Paz' 'Tanzania' 'Southwestern Colombia' 'Northern Guatemala' 'Hawaii'
#  'Comayagua Department' 'Chiapas State' 'Drc Congo' 'Kayanza Province'
#  'Northern Burundi' 'Mogiana' 'Hawai’I' 'Gedeb District'
#  '“Big Island” Of Hawaii' 'Bolivia' 'Jaén' 'Cauca Department' 'Gayo'
#  'Chia-Yi City' 'Cartago Province' 'China'
#  'The Democratic Republic Of The Congo' 'Chaiyi' 'Puna District'
#  'Galapagos Islands' 'South Africa' 'Northwest Colombia' 'Gedeb' 'Ka’U'
#  '"Big Island" Of Hawai’I' 'Southwestern Kenya' 'Western Kenya' 'Haiti'
#  'San Augustin' 'Eastern Highlands' 'Sul De Minas' 'San Jose' 'Chiapas'
#  'Huehuetenango Department' 'Kona' 'Thailand' 'Comayagua' 'Sidama Region'
#  'Rift Valley Region' 'Taiwan' 'Alta Verapaz' 'Southwestern Tanzania'
#  'Villa Rica' 'Dominican Republic' '“Big Island” Of Hawai’I'
#  'Chiang Mai Province' 'East Timor' 'Oxampampa' 'Satipo Province'
#  'Hambela Wamena Woreda' 'Chumphon' 'Blue Pine Forest'
#  'El Progreso Department' 'Caldas' 'Loja Province' 'Tabaconas'
#  'Lempira Department' 'Rulindo District' 'Kona District'
#  'Zamora Chinchipe' 'Sidama Growing Region' 'La Argentina' 'San Agustín'
#  'Oaxaca State' 'Fraijanes Plateau' 'San Marcos Department' 'Coatepeque'
#  'Volcán Santa Ana' 'Sandia Valley' 'West Valley' 'Jinotega' 'Chiang Rai'
#  'Eastern Highlands Province' 'Loja Region' 'Jambi Province' 'Aceh Tengah'
#  'Bugisu Region' 'Valle Del Cauca Department' 'Southern Rwanda'
#  'Chiriquí Province' 'Jiwaka Province' 'Sabanilla De Alajuela'
#  'Bure Woreda' 'Valle De Cauca Department' 'Oxapampa Province'
#  'Nariño Department' 'Bule Hora District' 'Mbozi District' 'Chia-Yi'
#  'Tarrazú' 'Eastern Jamaica.' 'Acevedo' 'Western Rwanda' 'Cajamarca'
#  'Bani Matar Growing Region' 'Huila Province' 'Santander Department'
#  'Santa Elena Province' 'Ngorongoro Conservation Area' 'El Progreso'
#  'Lake Atitlan' 'Sierra De Las Minas' 'Borena Hagermariam District'
#  'Vietnam' 'Santa Ana Department' 'Calzontes Arriba' 'Al Hayma District'
#  'San Ignacio Province' 'North Kona' 'Ana Sora District'
#  'Flores And Sumatra' 'Lincong' 'Puna' 'Western Guji' 'Guji'
#  'Puntarenas Province' 'Alajuela Province' 'Boquete' 'Renacimiento'
#  'Philippines' 'Antigua' 'Alta Verapaz Department' 'Valle Del Cauca'
#  'Tarrazu' 'Juayua' 'La Palma' 'Cantón El Tunel' 'Apaneca'
#  'Kona Growing Region' 'Chimborazo' 'Kerinci' 'Northern Sumatra Indonesia'
#  'Democratic Republic Of Congo' 'Chimborazo Province' 'Chirripó'
#  'Pasco Department' 'Pichincha' 'Indo-Pacific' 'Americas' 'Cusco'
#  'Southeastern Oahu' 'Miahuatlán' 'San Ignacio' 'Huye' 'Jiawaka Province'
#  'Big Island Of Hawai‘I' 'Simalungun' 'Haraaz' 'Sao Paulo State' 'Benguet'
#  'Pichincha Province' 'East Malaysia' 'Saraguro' 'Antioquia'
#  'Chirripo Region' 'Santa Barbara Department' 'Mbeya Growing Region'
#  'The Philippines' 'Tarrazú Growing Region' 'Turrubares'
#  'Imbabura Province' 'Snnp Region' 'Southwest Vietnam' 'Manizales'
#  'Veracruz State' 'Tolima' 'Nariño' 'Bensa District' 'Oaxaca'
#  'Nyeri County' 'Matagalpa Department' 'Loja' 'Chiayi County'
#  'Intibucá Department' 'Quindio Department' 'Djimma Growing Region'
#  'Guatemala Department' 'Lake Kivu' 'Lake Atitlán Growing Region']
# Unique values in roaster: ['A.R.C.' 'Revel Coffee' 'Roast House' 'Big Creek Coffee Roasters'
#  'Red Rooster Coffee Roaster' "Willoughby's Coffee & Tea"
#  'Black Oak Coffee Roasters' 'Wonderstate Coffee' 'Reunion Island Coffee'
#  "PT's Coffee Roasting" 'Kakalove Cafe' 'Level Ground Trading'
#  'Old Soul Co.' 'Bootstrap Coffee Roasters' 'Paradise Roasters'
#  'Hula Daddy Kona Coffee' 'Jackrabbit Java' 'Propeller Coffee'
#  'Chocolate Fish Coffee Roasters' 'Caffe Luxxe' 'Espresso Republic'
#  'Lexington Coffee Roasters' 'Noble Coffee Roasting' 'Red E Café'
#  "Ben's Beans" 'Speckled Ax' 'Fumi Coffee' 'Good Folks Coffee'
#  'Flight Coffee Co.' 'Dragonfly Coffee Roasters' 'OQ Coffee Co.'
#  'Green Stone Coffee' 'Bird Rock Coffee Roasters' 'Equator Coffees & Teas'
#  'JBC Coffee Roasters' 'Klatch Coffee' 'Campos Coffee'
#  "Ka'u Specialty Coffee" 'Simon Hsieh’s Aroma Roast Coffees'
#  'Amavida Coffee Roasters' 'Hala Tree Kona Coffee'
#  'Barrington Coffee Roasting' 'The WestBean Coffee Roasters'
#  'Mystic Monk Coffee' 'Good Chance Biotechnology, Ltd.'
#  'Manzanita Roasting Company' 'Temple Coffee and Tea' 'Magnolia Coffee'
#  'Charlotte Coffee Company' 'Water Avenue Coffee' 'Corvus Coffee Roasters'
#  "Per'la Specialty Roasters" 'Durango Coffee Company'
#  'Java Blend Coffee Roasters' 'Big Shoulders Coffee' 'Caffeic'
#  'Grounds for Change' 'Allegro Coffee' 'Mr. Espresso'
#  'Greater Goods Coffee Roasters' 'Tico Coffee Roasters' 'Cafe Douceur'
#  'Roasters Note' "Evie's Cafe" 'Hatch Coffee' 'Soul Work Coffee'
#  'Coffee Please' 'Peri Coffee' 'Montana Coffee Traders' 'Moore Coffee'
#  'Argyle Coffee Roasters' "Rusty's Hawaiian Coffee"
#  'Bluebeard Coffee Roasters' 'Creation Food Co.'
#  'Conscious Cup Coffee Roasters' 'Modern Times Coffee' 'Direct Coffee'
#  'Nook Bakery & Coffee Bar' 'Novel Coffee Roasters' 'Back Home Coffee'
#  'Auto Coffee' 'Aether Coffee' 'The Curve Coffee Roasting Co.'
#  'Mustard Seed Cafe' 'Novo Coffee' 'Oughtred Roasting Works'
#  'Oceana Coffee' 'Olympia Coffee Roasting' 'Small Eyes Cafe'
#  "Lin's Home Roasters" 'Pop Coffee Works' 'Barefoot Coffee Roasters'
#  'Taokas Coffee' 'States Coffee & Mercantile' "PT's Coffee Roasting Co."
#  'Crown & Fancy' 'MoonMoon Coffee' 'Difference Coffee' 'Good Coffee Club'
#  'Red Rock Roasters' 'Evans Brothers Coffee Roasters'
#  'Sweet Bloom Coffee Roasters' 'Desert Sun Coffee Roasters'
#  "Simon Hsieh's Aroma Roast Coffees" '709 Boutique Coffee'
#  'Vienna Coffee Company' 'North Coast Coffee Roasting'
#  'Steady State Roasting Company' 'Branch Street Coffee Roasters'
#  'Gorilla Conservation Coffee' 'GK Coffee' "Augie's Coffee Roasters"
#  'Hale Coffee Company' 'Equator Coffees' 'Ho Soo Tsai'
#  'Joe Van Gogh Coffee' "Mi's Cafe" 'Topeca Coffee Roasters'
#  'Steadfast Coffee' 'Broadsheet Coffee' 'De Clieu Coffee'
#  'Turnstile Coffee Roasters' 'Blues Brew Coffee' 'Doi Chaang Coffee'
#  'Temple Coffee Roasters' 'Choosy Gourmet' 'Café Grumpy' 'Kaffetre'
#  'Thanksgiving Coffee Company' 'Origin Coffee Roasters' 'Speedwell Coffee'
#  'Gracenote Coffee Roasters' 'Tandem Coffee'
#  'Vermont Artisan Coffee & Tea' 'Plat Coffee Roastery' 'Santos Coffee'
#  'Peach Coffee Roasters' 'Jampot Poorock Abbey'
#  'Wild Goose Coffee Roasters' 'The Curve Coffee Roasting' 'Cafe Virtuoso'
#  'Small Eyes Café' 'Notch Coffee' 'Giv COFFEE'
#  'Big Island Coffee Roasters' 'Nine Point Coffee' "Rusty's Hawaiian"
#  'Three Chairs Specialty Turkish Coffee' 'Greenwell Farms'
#  'Beanfruit Coffee Co.' 'Dou Zhai Coffee & Roast' 'Baba Java Coffee'
#  'DoDo Kaffa' 'Dory Coffee Roasters' 'SkyTop Coffee' 'Collage Coffee'
#  'Highwire Coffee Roasters' 'Folly Coffee Roasters' 'Kauai Coffee Company'
#  '94 Fresh Coffee' 'Finca Las Nieves' 'Pro Aroma Enterprise Coffee'
#  'Good Chance Biotechnology' 'Dinwei Cafe' 'Deeper Roots Coffee'
#  'Duluth Coffee' 'Kakalove Café' 'CafeTaster' 'Mudhouse Coffee Roasters'
#  'HWC Roasters' 'Dante Coffee' 'MJ Bear Coffee'
#  'Foggy Hills Coffee Company' 'Coffeebar' 'Pedestrian Coffee'
#  'Stereo Coffee Roasters' 'Tehmag Foods Corporation'
#  'Coava Coffee Roasters' 'Lucky Cafe' 'Hsus Cafe' 'Cafe Grumpy'
#  'South Slope Coffee Roasters' 'Souvenir Coffee' 'Q Burger'
#  '4 Plus Coffee' 'Black & White Coffee Roasters' 'Quartet Kaffe'
#  'MK Coffee Roasters' 'Wheelys Cafe Taiwan' 'Chez Cafe'
#  'San Francisco Bay Coffee' 'Detour Coffee Roasters' 'Open Seas Coffee'
#  "Peet's Coffee" 'Battlecreek Coffee Roasters' 'Press House Coffee'
#  'Guorizi Zhai Coffee' 'Black Coffee In Black Jar' 'Rotate Fun Club'
#  "Larry's Coffee" 'Allegro Coffee Roasters' 'Cafe Femenino' '3-19 Coffee'
#  'Joe Van Gogh' 'Signature Reserve' 'Cameron’s Coffee' 'HT Traders'
#  "Eight O'Clock Coffee" "Hill's Bros. Coffee" 'Starbucks Coffee'
#  'Euphora Coffee' 'Cloud City Coffee' 'Vascobelo' 'Counter Culture Coffee'
#  'Jampot Poorrock Abbey' 'Telluride Coffee Roasters' 'Kona Farm Direct'
#  'Lone Coffee' 'Indaba Coffee Roasters' 'Fire Ridge Coffee'
#  "Tony's Coffee" 'Dapper & Wise' 'Ghost Town Coffee Roasters'
#  'BeanFruit Coffee Co.' 'modcup coffee' 'Kona Roasted' 'Vennel Coffee'
#  'Oak & Bond Coffee Company' 'Mooju Coffee' 'Fidalgo Coffee'
#  'Rhetoric Coffee' 'RamsHead Coffee Roasters' 'Bonfire Coffee Company'
#  'Atom Coffee Roasters' 'RND & Red Rooster Coffee Roaster'
#  'Wheelys Café Taiwan' "David's Nose" 'Brain Helmet'
#  'Atomic Coffee Roasters' 'Cafe Arles' 'Equiano Coffee'
#  'Boon Boona Coffee' 'BLK & Bold' 'Dávila Kafe' 'Merge Coffee Company'
#  'Portrait Coffee' 'Kahawa 1893' 'Red Bay Coffee' 'RND'
#  'Southeastern Roastery' "Dr. Bean's Coffee Roasters"
#  'Drink Coffee Do Stuff' '421 Brew House' 'Emiliani Coffee'
#  'Triple Coffee Co.' 'CofFeeling' 'Peacock Coffee Roaster'
#  'Lamppost Coffee Roasters' 'Nostalgia Coffee Roasters' "Kaldi's Coffee"
#  'Beachcomber Coffee' 'States Coffee' 'Rooster Roastery'
#  'The Formosa Coffee' 'Bona Kafo Roastery' 'Miranda Farms'
#  'Jaunt Coffee Roasters' 'Steady State Roasting' 'El Gran Café'
#  'Tug Hill Artisan Roasters' 'Three Keys Coffee' 'Singsun Coffee'
#  'MT49 Cafe' 'El Gran Café ' 'Bridge Coffee Co.' 'Cafe Kreyol'
#  'Simon Hsieh Aroma Roast Coffees' 'Theory Coffee Roasters'
#  "Sunny's Coffee" 'Finca Tasta' 'Normandy Coffee Thai Cuisine'
#  'Red Bean Coffee' 'NINETYs Roastery' 'Kafe 1804' 'Brioso Coffee'
#  'Spirit Animal Coffee' 'One Fresh Cup' 'Prairie Lily Coffee' 'RD Cafe'
#  'Badbeard’s Microroastery' 'Regent Coffee' 'Old World Coffee Lab'
#  'SOT Coffee Roaster' 'Wildgoose Coffee Roasters'
#  'Sip of Hope Community Coffee Roasters' '1951 Coffee Company'
#  'Lina Premium Coffee' 'RanGuo Coffee' 'Roadmap CoffeeWorks'
#  'True Coffee Roasters' 'Coffee By Design' 'Islamorada Coffee Roasters'
#  'Cheer Beans' 'Jade Cafe' 'Big Shoulders Coffee '
#  'Colibrije Specialty Coffee' 'Desolate Cafe' 'Geisha Coffee Roaster'
#  'Café Hubert Saint-Jean' "Ming's Coffee Playroom" 'Raggiana Coffee'
#  'Pamma Coffee' 'Volcanica Coffee' 'Olympia Coffee' 'Mamechamame Coffee'
#  'Valverde Coffee Roasters' 'Le Brewlife' 'Rusty’s Hawaiian'
#  'Forest Roasting' 'Japanese Coffee Co.' 'LECO Coffee' 'EK Roast Studio'
#  'Home in Harmony' 'Toca Coffee' 'Tribo Coffee' 'Taster’s Coffee'
#  'Warm Air Kafe' 'Mr. Chao Coffee' 'Novo Coffee Roasters' 'Qin Mi Coffee'
#  'Hidden Coffee HK' 'Fresh Roasted Coffee' 'Eagle Valley Coffee'
#  'Metropolis Coffee' 'Coffee by Design' 'VN Beans' "Taster's Coffee"
#  'Cafe Unido' 'Port of Mokha' 'Chromatic Coffee' 'Qima Coffee'
#  'Kona Love Coffee Co.' 'Samlin Coffee' 'Chu Bei' 'Genesis Coffee Lab'
#  'Omine Coffee' 'T.S.E. Custom Roastery' 'Café Chiayi J11'
#  "King's Gambit Coffee" 'PT’s Coffee Roasting Co.' 'Mute Roaster'
#  'El Gran Cafe' 'Luv Moshi' 'VERYTIME' 'Evie’s Cafe'
#  'Doho Coffee Roasters' 'Folklore Coffee' 'Flower Coffee Workshop'
#  'Fumi Coffee Company' 'Cafe Red Bean Shop' 'Battlecreek Coffee'
#  'St1 Cafe/Work Room' 'Succulent Coffee Roasters'
#  'Battle Creek Coffee Roasters' 'A&E Coffee & Tea'
#  'Satur Specialty Coffee' 'Treeman Coffee' 'Tipico Coffee'
#  'Chaos Coffee Company' 'Monarch Coffee' 'Hey Brown' 'Ba Yang Coffee'
#  'Min Enjoy Cafe' 'Temple Coffee' 'Mostra Coffee' 'Roadmap Coffeeworks'
#  'Ramshead Coffee Roasters' 'Cozy House Coffee' 'Yellow Brick Coffee'
#  "Spix's Cafe" '1980 CAFE' 'Kasasagi Coffee Roasters'
#  'Hub Coffee Roasters' 'Rusty Dog Coffee' 'Felala Coffee Lab' 'Buon Caffe'
#  'Coffee Hound' 'Handlebar Coffee' 'The Reverse Orangutan'
#  'Barrington Coffee Roasting Co.' 'Madness Roastworks' 'Dear John Coffee'
#  'Cafe Fugu Roasters' 'Trident Coffee' 'Desolate Café' 'Brand 425'
#  'Per’la Specialty Roasters' 'Cup to Cup Coffee Roasters'
#  'Fieldheads Coffee Roasting' 'Water Street Coffee' 'Kona View Coffee'
#  'inLove Cafe' 'Muka Coffee' 'Chousin Coffee Collection' 'Vivid Coffee'
#  'Press Coffee' 'Golin Coffee Roasters' 'The Angry Roaster'
#  'AKA Coffee Roasters' 'Bassline Coffee' "Blanchard's Coffee"
#  'ILSE Coffee Roasters' 'Rest Coffee Roasters' 'Swelter Coffee'
#  'Sightseer Coffee' 'Bargain Cafe' 'Rubasse Coffee Roaster'
#  'Chiming Coffee' 'JYL Cafe' 'Balmy Day Coffee Office' 'Dr. Young Cafe'
#  'Euphora' 'San Francisco Bay Coffee Company' 'Durango Coffee Companuy']

# %% [markdown]
# # Supervised ML

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestRegressor

from scipy.sparse import hstack, csr_matrix

y = df["rating"]
X = df[[text_col] + num_cols + cat_cols]

X_train, X_test, y_train, y_test = train_test_split(
    df, y, test_size=0.2, random_state=42
)

X_train_cat = pd.get_dummies(X_train[cat_cols], drop_first=False, dtype=int)
X_test_cat  = pd.get_dummies(X_test[cat_cols], drop_first=False, dtype=int)

# Align columns
X_test_cat = X_test_cat.reindex(columns=X_train_cat.columns, fill_value=0)

# Standardize
scaler = StandardScaler()
X_train_num = scaler.fit_transform(X_train[num_cols])
X_test_num = scaler.transform(X_test[num_cols])

X_train_num = csr_matrix(X_train_num)
X_test_num  = csr_matrix(X_test_num)

# TF-IDF
# Handle NaN values in the text column by filling them with empty strings
X_train[text_col] = X_train[text_col].fillna("").astype(str)
X_test[text_col] = X_test[text_col].fillna("").astype(str)

tfidf = TfidfVectorizer(max_features=3000, stop_words="english")
X_train_text = tfidf.fit_transform(X_train[text_col])
X_test_text  = tfidf.transform(X_test[text_col])

# splice all data
X_train_all = hstack([X_train_text, csr_matrix(X_train_cat), X_train_num])
X_test_all  = hstack([X_test_text, csr_matrix(X_test_cat), X_test_num])

# %% [markdown]
# # 1. Linear Regression

# %%
# Training the model
model = LinearRegression()
model.fit(X_train_all, y_train)

# Making predictions
y_pred = model.predict(X_test_all)

# Evaluating the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
print(f'R2 Score: {r2}')
# Out:
# Mean Squared Error: 1.8167602186883474
# R2 Score: 0.24541207911076612

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual vs Predicted Prices")
plt.show()

# %% [markdown]
# The R2 score is low, fit badly.

# %% [markdown]
# # 2. RandomForest

# %%
model = RandomForestRegressor()
model.fit(X_train_all, y_train)

# Making predictions
y_pred = model.predict(X_test_all)

# Evaluating the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
print(f'R2 Score: {r2}')
# Out:
# Mean Squared Error: 0.9288782816229115
# R2 Score: 0.6141921624665235

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual vs Predicted Prices")
plt.show()

# %% [markdown]
# Fit fairly good from the R2 score

# %% [markdown]
# # Unsupervised

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from ucimlrepo import fetch_ucirepo

# %%
cat_cols2 = ["loc_country", "roaster", "roast"]
num_cols2 = ["100g_USD", "rating"]
df_cat = pd.get_dummies(df[cat_cols2], dtype=int)
scaler = StandardScaler()
df_num = scaler.fit_transform(df[num_cols2])

df["text"] = df["text"].fillna("")
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("all-MiniLM-L6-v2")

emb_text = model.encode(
    df["text"].tolist(),
    show_progress_bar=True,
    convert_to_numpy=True
)
# Combine all features
X_all = np.hstack([
    emb_text,
    df_cat.values,
    df_num
])

print("Final feature shape:", X_all.shape)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/66 [00:00<?, ?it/s]
# Final feature shape: (2095, 834)

# %%
X = X_all

inertias = []
sil_scores = []
K_range = range(2, 11)

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init='auto')
    labels = kmeans.fit_predict(X)

    inertias.append(kmeans.inertia_)
    sil_scores.append(silhouette_score(X, labels))

# Plot Elbow
plt.figure(figsize=(12,5))
plt.plot(K_range, inertias, marker='o')
plt.title("Elbow Curve")
plt.xlabel("k")
plt.ylabel("Inertia")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(K_range, sil_scores, marker='o')
plt.title("Silhouette Score by k")
plt.xlabel("k")
plt.ylabel("Silhouette Score")
plt.grid(True)
plt.show()

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA

# Perform PCA
pca = PCA(n_components=2)  # Reduce to 2 components for visualization
pca_data = pca.fit_transform(X_all)

# %%
# Visualize PCA-reduced data
plt.scatter(pca_data[:, 0], pca_data[:, 1], alpha=0.7, edgecolor='k')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.title('PCA-reduced Data')
plt.show()

# %%
# Determine optimal number of clusters using Elbow Method
inertia = []
silhouette_scores = []
k_values = range(2, 11)

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(pca_data)
    inertia.append(kmeans.inertia_)
    silhouette_scores.append(silhouette_score(pca_data, kmeans.labels_))

# %%
# Plot Elbow Method
plt.plot(k_values, inertia, marker='o')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Method for Optimal k')
plt.show()

# %%
# Plot Silhouette Scores
plt.plot(k_values, silhouette_scores, marker='o', color='orange')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Scores for Different k')
plt.show()

# %%
optimal_k = 5
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
kmeans.fit(pca_data)

# Add cluster labels to the original dataset
df['Cluster'] = kmeans.labels_

# Visualize the clustered PCA-reduced data
plt.scatter(pca_data[:, 0], pca_data[:, 1], c=kmeans.labels_, cmap='viridis', alpha=0.7, edgecolor='k')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.title(f'K-means Clustering with {optimal_k} Clusters (PCA-reduced Data)')
plt.colorbar(label='Cluster')
plt.show()

# %% [markdown]
# The Silhouette Scores of the PCA is high, showing good performance, we can clearly see several distinct groups.

# %%
# Top key words of the clusters
vectorizer = TfidfVectorizer(
    stop_words="english",
    max_features=5000,
    ngram_range=(1, 2),
)
tfidf_matrix = vectorizer.fit_transform(df["text"])
feature_names = vectorizer.get_feature_names_out()
labels = kmeans.fit_predict(X_all)

# explain every clusters
def top_keywords(cluster_id, top_n=20):
    idx = np.where(labels == cluster_id)[0]
    cluster_tfidf = tfidf_matrix[idx].mean(axis=0).A1
    top_idx = cluster_tfidf.argsort()[::-1][:top_n]
    return feature_names[top_idx]

# Key num_data of clusters
num_cols = ["100g_USD", "rating"]

def numeric_profile(cluster_id):
    return df[df.Cluster == cluster_id][num_cols].mean()

# Key categories of clusters
cat_cols = ["roaster", "roast", "loc_country", "origin_1", "origin_2"]

def categorical_top(cluster_id, top_n=5):
    res = {}
    subset = df[df.Cluster == cluster_id]

    for col in cat_cols:
        res[col] = subset[col].value_counts().head(top_n)
    return res

for c in sorted(df.Cluster.unique()):
    print("\n===============================")
    print(f" 📌Cluster {c}")
    print("===============================")

    print("\n Top Keywords:")
    print(top_keywords(c, 10))

    print("\n Numeric Features (mean):")
    print(numeric_profile(c))

    print("\n Categorical Features (top values):")
    cat = categorical_top(c)
    for col, vals in cat.items():
        print(f"\n  - {col}:")
        print(vals)
print(df["Cluster"].value_counts().sort_index())
# Out:
# ===============================
#  📌Cluster 0
# ===============================
#
#  Top Keywords:
# ['email' 'coffee' 'taiwan' 'fruit' 'chocolate' 'espresso' 'sweet' 'toned'
#  'cup' 'ethiopia']
#
#  Numeric Features (mean):
# 100g_USD    27.100769
# rating      94.532967
# dtype: float64
#
#  Categorical Features (top values):
#
#   - roaster:
# roaster
# Paradise Roasters            47
# Hula Daddy Kona Coffee       23
# Dragonfly Coffee Roasters    11
# Kakalove Cafe                10
# Bird Rock Coffee Roasters     9
# Name: count, dtype: int64
#
#   - roast:
# roast
# Medium-Light    128
# Light            40
# Medium           11
# Medium-Dark       1
# Name: count, dtype: int64
#
#   - loc_country:
# loc_country
# United States    102
# Taiwan            39
# Hawai'i           34
# Hong Kong          3
# Japan              2
# Name: count, dtype: int64
#
#   - origin_1:
# origin_1
# Holualoa                  34
# Boquete Growing Region    15
# Kona                       9
# Piedra Candela             6
# Chiriqui Province          5
# Name: count, dtype: int64
#
#   - origin_2:
# origin_2
# North Kona Growing District    26
# Big Island Of Hawai’I          21
# Western Panama                 15
# Colombia                       12
# Panama                         11
# Name: count, dtype: int64
#
# ===============================
#  📌Cluster 1
# ===============================
#
#  Top Keywords:
# ['coffee' 'sweet' 'chocolate' 'toned' 'cup' 'coffees' 'nut' 'fruit'
#  'cocoa' 'cedar']
#
#  Numeric Features (mean):
# 100g_USD     5.713277
# rating      90.117647
# dtype: float64
#
#  Categorical Features (top values):
#
#   - roaster:
# roaster
# JBC Coffee Roasters         11
# El Gran Cafe                11
# Paradise Roasters            8
# Espresso Republic            8
# San Francisco Bay Coffee     8
# Name: count, dtype: int64
#
#   - roast:
# roast
# Medium-Light    125
# Medium           75
# Light            19
# Medium-Dark      14
# Dark              4
# Name: count, dtype: int64
#
#   - loc_country:
# loc_country
# United States    168
# Taiwan            32
# Guatemala         15
# Hawai'i           10
# Japan              4
# Name: count, dtype: int64
#
#   - origin_1:
# origin_1
# Guji Zone                     13
# Colombia                      10
# Ethiopia                       9
# Yirgacheffe Growing Region     9
# Brazil                         8
# Name: count, dtype: int64
#
#   - origin_2:
# origin_2
# Guatemala            27
# Colombia             22
# Oromia Region        13
# Southern Ethiopia    10
# Ethiopia             10
# Name: count, dtype: int64
#
# ===============================
#  📌Cluster 2
# ===============================
#
#  Top Keywords:
# ['coffee' 'fruit' 'coffees' 'sweet' 'cup' 'processed' 'toned' 'cocoa'
#  'arabica' 'chocolate']
#
#  Numeric Features (mean):
# 100g_USD     6.508563
# rating      92.615625
# dtype: float64
#
#  Categorical Features (top values):
#
#   - roaster:
# roaster
# JBC Coffee Roasters         64
# Paradise Roasters           44
# Temple Coffee Roasters      32
# Kakalove Cafe               32
# RamsHead Coffee Roasters    24
# Name: count, dtype: int64
#
#   - roast:
# roast
# Medium-Light    714
# Medium          123
# Light           106
# Medium-Dark      13
# Name: count, dtype: int64
#
#   - loc_country:
# loc_country
# United States    648
# Taiwan           234
# Hawai'i           30
# Canada            18
# Guatemala         10
# Name: count, dtype: int64
#
#   - origin_1:
# origin_1
# Yirgacheffe Growing Region    57
# Guji Zone                     49
# Ethiopia                      46
# Colombia                      19
# Brazil                        19
# Name: count, dtype: int64
#
#   - origin_2:
# origin_2
# Guatemala            85
# Southern Ethiopia    64
# Colombia             59
# Oromia Region        47
# Costa Rica           40
# Name: count, dtype: int64
#
# ===============================
#  📌Cluster 3
# ===============================
#
#  Top Keywords:
# ['geisha' 'nespresso' 'coffee' 'civet' 'capsule' 'compatible' 'luwak'
#  'gesha' 'cat' 'civet cat']
#
#  Numeric Features (mean):
# 100g_USD    92.977826
# rating      94.652174
# dtype: float64
#
#  Categorical Features (top values):
#
#   - roaster:
# roaster
# Difference Coffee                  6
# Good Chance Biotechnology, Ltd.    4
# Paradise Roasters                  4
# Dragonfly Coffee Roasters          1
# Good Chance Biotechnology          1
# Name: count, dtype: int64
#
#   - roast:
# roast
# Medium-Light    12
# Light            5
# Medium-Dark      1
# Name: count, dtype: int64
#
#   - loc_country:
# loc_country
# United States    8
# Taiwan           7
# England          6
# Australia        1
# China            1
# Name: count, dtype: int64
#
#   - origin_1:
# origin_1
# Boquete Growing Region                 8
# Sidamo Growing Region                  3
# Sidamo (Also Sidama) Growing Region    2
# San Jose De Minas                      2
# Ngorongoro                             2
# Name: count, dtype: int64
#
#   - origin_2:
# origin_2
# Western Panama            8
# South-Central Ethiopia    5
# Pichincha                 2
# Tanzania                  2
# Far Western Panama        1
# Name: count, dtype: int64
#
# ===============================
#  📌Cluster 4
# ===============================
#
#  Top Keywords:
# ['coffee' 'fruit' 'coffees' 'sweet' 'cup' 'toned' 'chocolate' 'cocoa'
#  'processed' 'notes']
#
#  Numeric Features (mean):
# 100g_USD     7.013772
# rating      94.411850
# dtype: float64
#
#  Categorical Features (top values):
#
#   - roaster:
# roaster
# Kakalove Cafe                 99
# JBC Coffee Roasters           81
# Paradise Roasters             32
# Red Rooster Coffee Roaster    26
# GK Coffee                     21
# Name: count, dtype: int64
#
#   - roast:
# roast
# Medium-Light    511
# Light           117
# Medium           50
# Medium-Dark      10
# Dark              1
# Name: count, dtype: int64
#
#   - loc_country:
# loc_country
# United States    410
# Taiwan           242
# Hawai'i           13
# Canada             9
# Hong Kong          7
# Name: count, dtype: int64
#
#   - origin_1:
# origin_1
# Guji Zone                     70
# Yirgacheffe Growing Region    42
# Nyeri Growing Region          39
# Ethiopia                      21
# Kirinyaga District            17
# Name: count, dtype: int64
#
#   - origin_2:
# origin_2
# South-Central Kenya       75
# Southern Ethiopia         66
# Oromia Region             64
# Colombia                  48
# South-Central Ethiopia    28
# Name: count, dtype: int64
# Cluster
# 0    182
# 1    238
# 2    960
# 3     23
# 4    692
# Name: count, dtype: int64
